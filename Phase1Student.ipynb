# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("datasets/nas-pupil-marks.csv")

# %%
df1.head()
# Out:
#             STUID State  District  Gender  Age  Category  Same_language  \
# 1087  11021040001    AP         2       2    3         1              1
# 1088  11021040002    AP         2       2    1         2              2
# 1090  11021040004    AP         2       2    4         3              1
# 1091  11021040005    AP         2       2    2         3              1
# 1092  11021040006    AP         2       2    3         3              1
#
#       Siblings  Handicap  Father_edu  ...  Express_science_views  Watch_TV  \
# 1087         2         2           2  ...                      3         4
# 1088         3         2           2  ...                      3         4
# 1090         2         2           1  ...                      3         4
# 1091         2         2           2  ...                      3         4
# 1092         3         2           2  ...                      3         4
#
#       Read_magazine  Read_a_book  Play_games Help_in_household  Maths_Percent  \
# ...

# %%
print("Rows:", df1.shape[0], "Columns:", df1.shape[1])
df1.info()

df1.isnull().sum()
# Out:
# Rows: 8044 Columns: 64
# <class 'pandas.core.frame.DataFrame'>
# Index: 8044 entries, 1087 to 185347
# Data columns (total 64 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   STUID                   8044 non-null   int64
#  1   State                   8044 non-null   object
#  2   District                8044 non-null   int64
#  3   Gender                  8044 non-null   int64
#  4   Age                     8044 non-null   int64
#  5   Category                8044 non-null   int64
#  6   Same_language           8044 non-null   int64
#  7   Siblings                8044 non-null   int64
#  8   Handicap                8044 non-null   int64
#  9   Father_edu              8044 non-null   int64
#  10  Mother_edu              8044 non-null   int64
#  11  Father_occupation       8044 non-null   int64
#  12  Mother_occupation       8044 non-null   int64
#  13  Below_poverty           8044 non-null   int64
# ...

# %%
df1 = df1.drop_duplicates()
df1.head()
# Out:
#             STUID State  District  Gender  Age  Category  Same_language  \
# 1087  11021040001    AP         2       2    3         1              1
# 1088  11021040002    AP         2       2    1         2              2
# 1090  11021040004    AP         2       2    4         3              1
# 1091  11021040005    AP         2       2    2         3              1
# 1092  11021040006    AP         2       2    3         3              1
#
#       Siblings  Handicap  Father_edu  ...  Express_science_views  Watch_TV  \
# 1087         2         2           2  ...                      3         4
# 1088         3         2           2  ...                      3         4
# 1090         2         2           1  ...                      3         4
# 1091         2         2           2  ...                      3         4
# 1092         3         2           2  ...                      3         4
#
#       Read_magazine  Read_a_book  Play_games Help_in_household  Maths_Percent  \
# ...

# %%
df1 = df1.dropna()
df1.head(10)
# Out:
#             STUID State  District  Gender  Age  Category  Same_language  \
# 1087  11021040001    AP         2       2    3         1              1
# 1088  11021040002    AP         2       2    1         2              2
# 1090  11021040004    AP         2       2    4         3              1
# 1091  11021040005    AP         2       2    2         3              1
# 1092  11021040006    AP         2       2    3         3              1
# 1093  11021040007    AP         2       2    3         3              1
# 1094  11021040008    AP         2       2    0         3              1
# 1095  11021040009    AP         2       2    3         3              1
# 1096  11021040010    AP         2       2    4         3              1
# 1097  11021040011    AP         2       2    3         3              1
#
#       Siblings  Handicap  Father_edu  ...  Express_science_views  Watch_TV  \
# 1087         2         2           2  ...                      3         4
# ...

# %%
df1.columns = df1.columns.str.strip().str.replace(" ", "_").str.replace("%", "Percent")
df1.head()
# Out:
#             STUID State  District  Gender  Age  Category  Same_language  \
# 1087  11021040001    AP         2       2    3         1              1
# 1088  11021040002    AP         2       2    1         2              2
# 1090  11021040004    AP         2       2    4         3              1
# 1091  11021040005    AP         2       2    2         3              1
# 1092  11021040006    AP         2       2    3         3              1
#
#       Siblings  Handicap  Father_edu  ...  Express_science_views  Watch_TV  \
# 1087         2         2           2  ...                      3         4
# 1088         3         2           2  ...                      3         4
# 1090         2         2           1  ...                      3         4
# 1091         2         2           2  ...                      3         4
# 1092         3         2           2  ...                      3         4
#
#       Read_magazine  Read_a_book  Play_games Help_in_household  Maths_Percent  \
# ...

# %%
df1 = df1.dropna(thresh=5)
df1.head()
# Out:
#             STUID State  District  Gender  Age  Category  Same_language  \
# 1087  11021040001    AP         2       2    3         1              1
# 1088  11021040002    AP         2       2    1         2              2
# 1090  11021040004    AP         2       2    4         3              1
# 1091  11021040005    AP         2       2    2         3              1
# 1092  11021040006    AP         2       2    3         3              1
#
#       Siblings  Handicap  Father_edu  ...  Express_science_views  Watch_TV  \
# 1087         2         2           2  ...                      3         4
# 1088         3         2           2  ...                      3         4
# 1090         2         2           1  ...                      3         4
# 1091         2         2           2  ...                      3         4
# 1092         3         2           2  ...                      3         4
#
#       Read_magazine  Read_a_book  Play_games Help_in_household  Maths_Percent  \
# ...

# %%
print(df1['STUID'].nunique(), len(df1))
# Out:
# 8043 8044
